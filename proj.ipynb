# %%
import pandas as pd
df = pd.read_csv('Smartphone_Dataset.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Display the first few rows of the dataset
df.head()
# Out:
#   transaction_id user_id  age gender  daily_screen_time_hours  \
# 0       TXN00001  U00001   21   Male                     3.23
# 1       TXN00002  U00002   24  Other                     5.09
# 2       TXN00003  U00003   31  Other                     6.06
# 3       TXN00004  U00004   32  Other                     7.83
# 4       TXN00005  U00005   25   Male                     9.96
#
#    social_media_hours  gaming_hours  work_study_hours  sleep_hours  \
# 0                2.01          0.89              4.55         7.55
# 1                3.81          2.24              4.44         7.66
# 2                1.36          3.83              2.35         4.92
# 3                5.85          1.51              3.54         8.23
# 4                5.92          3.42              5.27         6.21
#
#    notifications_per_day  app_opens_per_day  weekend_screen_time stress_level  \
# 0                    248                154                 3.95       Medium
# ...

# %%
# Get basic information about the dataset
print("Shape of the dataset:", df.shape)
print("\nData types and missing values:")
df.info()
print("\nSummary statistics for numerical columns:")
df.describe()
# Out:
# Shape of the dataset: (7500, 16)
#
# Data types and missing values:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           7500 non-null   object
#  1   user_id                  7500 non-null   object
#  2   age                      7500 non-null   int64
#  3   gender                   7500 non-null   object
#  4   daily_screen_time_hours  7500 non-null   float64
#  5   social_media_hours       7500 non-null   float64
#  6   gaming_hours             7500 non-null   float64
#  7   work_study_hours         7500 non-null   float64
#  8   sleep_hours              7500 non-null   float64
#  9   notifications_per_day    7500 non-null   int64
#  10  app_opens_per_day        7500 non-null   int64
#  11  weekend_screen_time      7500 non-null   float64
# ...

# %%
# Check for missing values
print("Missing values per column:")
df.isnull().sum()
# Out:
# Missing values per column:
# transaction_id               0
# user_id                      0
# age                          0
# gender                       0
# daily_screen_time_hours      0
# social_media_hours           0
# gaming_hours                 0
# work_study_hours             0
# sleep_hours                  0
# notifications_per_day        0
# app_opens_per_day            0
# weekend_screen_time          0
# stress_level                 0
# academic_work_impact         0
# addiction_level            819
# addicted_label               0
# dtype: int64

# %%
# Value counts for categorical columns
categorical_cols = ['gender', 'stress_level', 'academic_work_impact', 'addiction_level', 'addicted_label']
for col in categorical_cols:
    print(f"\nValue counts for {col}:")
    print(df[col].value_counts())
# Out:
# Value counts for gender:
# gender
# Male      2553
# Other     2486
# Female    2461
# Name: count, dtype: int64
#
# Value counts for stress_level:
# stress_level
# High      2560
# Low       2503
# Medium    2437
# Name: count, dtype: int64
#
# Value counts for academic_work_impact:
# academic_work_impact
# No     3753
# Yes    3747
# Name: count, dtype: int64
#
# Value counts for addiction_level:
# addiction_level
# Moderate    2874
# Severe      2434
# Mild        1373
# Name: count, dtype: int64
#
# Value counts for addicted_label:
# addicted_label
# 1    5308
# 0    2192
# Name: count, dtype: int64

# %%
# Histograms for numerical columns
numerical_cols = ['age', 'daily_screen_time_hours', 'social_media_hours', 'gaming_hours', 'work_study_hours', 'sleep_hours', 'notifications_per_day', 'app_opens_per_day', 'weekend_screen_time']
df[numerical_cols].hist(bins=20, figsize=(15, 10))
plt.tight_layout()
plt.show()

# %%
# Correlation heatmap for numerical columns
plt.figure(figsize=(12, 8))
sns.heatmap(df[numerical_cols].corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Boxplots for numerical columns by stress level
for col in numerical_cols:
    plt.figure(figsize=(8, 6))
    sns.boxplot(x='stress_level', y=col, data=df)
    plt.title(f'Boxplot of {col} by Stress Level')
    plt.show()
